# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(session_overlay)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/session.py#L90){target="_blank" style="float:right; font-size:smaller"}
#
# ### session_overlay
#
# >      session_overlay (data)
