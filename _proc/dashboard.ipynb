# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(WandbFigureFactory)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/dashboard.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### WandbFigureFactory
#
# >      WandbFigureFactory (entity='pporcher', project='tmaidev', samples=2000)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [raw]
# WandbFigureFactory(entity="trackmania-ai", project="tmaiprod").training_figure(
#     metric="mean_errors",
#     title="Training error in reward estimation (smoothed)",
#     ema=1000,
# )

# %% [raw]
# WandbFigureFactory().collect_figure(
#     metric="total_reward",
#     divisor="total_step_count",
#     title="Reward per step (ema 50)",
#     ema=50,
# )

# %% [raw]
# WandbFigureFactory().collect_figure(
#     metric="finish_racetime",
#     title="Finish time (ema 100)",
#     ema=500,
#     date_unit="ms",
#     tickformat="%M:%S.%L",
# )

# %% [raw]
# WandbFigureFactory().training_figure(
#     metric="mean_errors",
#     title="Training error in reward estimation (smoothed)",
#     ema=1000,
# )

# %% [markdown]
# ## Layout

# %%
#| echo: false
#| output: asis
show_doc(Dashboard)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/dashboard.py#L336){target="_blank" style="float:right; font-size:smaller"}
#
# ### Dashboard
#
# >      Dashboard (entity='pporcher', project='tmaidev', size={'width': 960,
# >                 'height': 540}, interval=15000, ema=50, debug=False,
# >                 border=False, port=8050)
#
# A class that represents a thread of control.
#
# This class can be safely subclassed in a limited fashion. There are two ways
# to specify the activity: by passing a callable object to the constructor, or
# by overriding the run() method in a subclass.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | entity | str | pporcher |  |
# | project | str | tmaidev |  |
# | size | dict | {'width': 960, 'height': 540} |  |
# | interval | int | 15000 | in milliseconds |
# | ema | int | 50 |  |
# | debug | bool | False |  |
# | border | bool | False |  |
# ...

# %%
#| echo: false
#| output: asis
show_doc(seconds2str)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/dashboard.py#L328){target="_blank" style="float:right; font-size:smaller"}
#
# ### seconds2str
#
# >      seconds2str (seconds)

# %% [raw]
# dashboard = Dashboard(entity="pporcher", project="tmaidev", border=True)
