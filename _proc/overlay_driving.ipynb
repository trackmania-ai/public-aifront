# %% [raw]
# ---
# output-file: overlay_driving.html
# title: Action
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(action_overlay)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/driving.py#L54){target="_blank" style="float:right; font-size:smaller"}
#
# ### action_overlay
#
# >      action_overlay (color)

# %% [markdown]
# # Progress

# %%
#| echo: false
#| output: asis
show_doc(progress_overlay)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/driving.py#L145){target="_blank" style="float:right; font-size:smaller"}
#
# ### progress_overlay
#
# >      progress_overlay ()
