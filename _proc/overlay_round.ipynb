# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(round_overlay)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/round.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### round_overlay
#
# >      round_overlay (data)
