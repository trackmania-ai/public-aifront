# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(medal_badges)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/medal.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### medal_badges
#
# >      medal_badges (medals)

# %%
#| echo: false
#| output: asis
show_doc(racetime2str)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/medal.py#L60){target="_blank" style="float:right; font-size:smaller"}
#
# ### racetime2str
#
# >      racetime2str (milliseconds)

# %%
#| echo: false
#| output: asis
show_doc(pb_badge)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/medal.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### pb_badge
#
# >      pb_badge (medals, best)

# %%
#| echo: false
#| output: asis
show_doc(pb_with_icon)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/medal.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### pb_with_icon
#
# >      pb_with_icon (medals, best, no_respawn=False)

# %%
#| echo: false
#| output: asis
show_doc(medal_icon)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/medal.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### medal_icon
#
# >      medal_icon (medal)
