# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(timeout_wrapper)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/default.py#L36){target="_blank" style="float:right; font-size:smaller"}
#
# ### timeout_wrapper
#
# >      timeout_wrapper (children, timeout, class_name='')

# %%
#| echo: false
#| output: asis
show_doc(table)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/default.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### table
#
# >      table (headers, rows)

# %%
#| echo: false
#| output: asis
show_doc(table_headers)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/default.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### table_headers
#
# >      table_headers (*args)

# %%
#| echo: false
#| output: asis
show_doc(table_row)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/default.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### table_row
#
# >      table_row (*args)
