# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Layout

# %%
#| echo: false
#| output: asis
show_doc(EnvOverlay)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/aifront/tree/master/blob/master/aifront/overlay/main.py#L171){target="_blank" style="float:right; font-size:smaller"}
#
# ### EnvOverlay
#
# >      EnvOverlay (color='rgb(229, 134, 6)', size={'width': 960, 'height': 540},
# >                  after_done_duration=5000, debug=False, border=False,
# >                  port=8051)
#
# A class that represents a thread of control.
#
# This class can be safely subclassed in a limited fashion. There are two ways
# to specify the activity: by passing a callable object to the constructor, or
# by overriding the run() method in a subclass.

# %% [raw]
# overlay = EnvOverlay(debug=False, border=True)
